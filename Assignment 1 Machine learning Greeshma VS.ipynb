# %% [markdown]
# #### 1. Write a function for mean, median, Q1, Q3, IQR. For Q1 and Q3, you can use your custom median function. Do not use any inbuilt python functions for median and mean. You can use only sort function if needed.

# %% [markdown]
# ### Solution

# %% [markdown]
# # Mean

# %% [raw]
# The mean value is the average value. To calculate the mean, find the sum of all values, and divide the sum by the number of values.

# %%
numb = [2, 3, 5, 7, 8]
no = len(numb)
summ = sum(numb)
mean = summ / no
print("The mean or average of all these numbers (", numb, ") is", str(mean))
# Out:
# The mean or average of all these numbers ( [2, 3, 5, 7, 8] ) is 5.0

# %% [markdown]
# # Median

# %% [raw]
# The median value is the value in the middle, after you have sorted all the values:

# %%
numb = [2, 4, 5, 8, 9,8]
no = len(numb)
numb.sort()
if no % 2 == 0:
    median1 = numb[no//2]
    median2 = numb[no//2 - 1]
    median = (median1 + median2)/2
else:
    median = numb[no//2]
print("The median of the given numbers  (", numb, ") is", str(median))
# Out:
# The median of the given numbers  ( [2, 4, 5, 8, 8, 9] ) is 6.5

# %% [markdown]
# # Quartiles

# %% [markdown]
# Quartiles are position indicators that divide a sequence of numbers into 4 equal parts.

# %% [markdown]
# ### First Quartiles

# %% [raw]
# The first quartile (Q1), is defined as the middle number between the smallest number and the median of the data set

# %% [markdown]
# ### First Quartiles for Odd number

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11,12]
no=len(data)
data.sort()
q2=data[no//2]
print(q2)
q1=(data[:q2-1])
num=len(q1)
print(q1)
a1=q1[num//2]
b1=q1[num//2 - 1]
q1=(a1+b1)/2
print(q1)
# Out:
# 7
# [2, 3, 3, 4, 4, 6]
# 3.5

# %% [markdown]
# ### First Quartiles for Even number

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11]
no=len(data)
data.sort()
a=data[no//2]
b=data[no//2-1]
q2=(a+b)/2
print(q2)
q1=data[:a-1]
print(q1)
num=len(q1)
print(num)
a1=data[num//2]
b1=data[num//2-1]
q1=(a1+b1)/2
print(q1)
# Out:
# 6.5
# [2, 3, 3, 4, 4, 6]
# 6
# 3.5

# %%
## First quartile for both odd number and even number

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11,12]
no=len(data)
data.sort()
if no % 2 == 0:
    a=data[no//2]
    b=data[no//2-1]
    q2=(a+b)/2
    q1=data[:a-1]
    print(q1)
    num=len(q1)
    a1=data[num//2]
    b1=data[num//2-1]
    q1=(a1+b1)/2
else:
    q2=data[no//2]
    q1=(data[:q2-1])
    num=len(q1)
    a1=q1[num//2]
    b1=q1[num//2 - 1]
    q1=(a1+b1)/2
    
print(q1)
# Out:
# 3.5

# %% [markdown]
# ### Third Quartiles

# %% [markdown]
# the third quartile (Q3), is the middle number between the median and the largest value of the data set

# %% [markdown]
# ### Third Quartiles for Odd Number

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11,12]
no=len(data)
data.sort()
q2=data[no//2]
q3=data[q2:]
print(q3)
num=len(q3)
a=q3[num//2]
b=q3[num//2-1]
q3=(a+b)/2
print(q3)
# Out:
# [7, 7, 8, 9, 11, 12]
# 8.5

# %% [markdown]
# ### Third Quartiles for Even Number

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11]
no=len(data)
data.sort()
a=data[no//2]
b=data[no//2-1]
q2=(a+b)/2
print(q2)
q3=data[b:]
num=len(q3)
print(q3)
print(num)
a1=q3[num//2]
b1=q3[num//2-1]
q3=(a1+b1)/2
print(q3)
# Out:
# 6.5
# [7, 7, 7, 8, 9, 11]
# 6
# 7.5

# %% [markdown]
# ### Interquartile range

# %% [raw]
# IQR (Interquartile Range) is the difference between the third and the first quartile of a distribution (or the 75th percentile minus the 25th percentile). It is a measure of how wide our distribution is since this range contains half of the points of the dataset.

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11,12]
no=len(data)
data.sort()
q2=data[no//2]
print(q2)
q1=(data[:q2-1])
num=len(q1)
print(q1)
a1=q1[num//2]
b1=q1[num//2 - 1]
q1=(a1+b1)/2
print(q1)
# Out:
# 7
# [2, 3, 3, 4, 4, 6]
# 3.5

# %%
data=[2,3,3,4,4,6,7,7,7,8,9,11,12]
no=len(data)
data.sort()
q2=data[no//2]
q3=data[q2:]
print(q3)
num=len(q3)
a=q3[num//2]
b=q3[num//2-1]
q3=(a+b)/2
print(q3)
# Out:
# [7, 7, 8, 9, 11, 12]
# 8.5

# %%
iqr=q3-q1
print(iqr)
# Out:
# 5.0

# %% [markdown]
# #### 2. Write a python code to find the average number of trails to obtain all six sides of a dice at least once. For example, if you roll a 6-sided dice for the first time, you can get any of the 6 sides (1,2,3,4,5,6). Let us say you get 3. When you roll it for the second time, you get 4. Next few rolls you got 5,2,3,1,6. You can stop rolling since you got all six sides at least once. Now, if you conduct this experiment for 10000 times, what is the average number of rolls?

# %% [markdown]
# ### Solution

# %%
import random
import numpy as np
avg=[]
j=0
while j<=10000:
    dice=[1,2,3,4,5,6]
    for i in range(1,10000):
        random_num = random.randint(1,6)
        if random_num in dice:
            dice.remove(random_num)
        if len(dice)==0:
            break
            avg.append(i) 
        else :
            i+1 
    avg.append(i)  
    j+=1
print(np.mean(avg))
# Out:
# 14.765723427657234

# %% [markdown]
# # 3.American Express - Default Prediction

# %% [markdown]
# # Importing Libraries :-

# %%
import os
import numpy as np 
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
import matplotlib
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %% [markdown]
# # Reading Data :

# %%
# loading the american dataset to a pandas DataFrame

# %%
traindata=pd.read_csv('C:/Users/91944/Desktop/INSOFE ASSIGNMENT/Assignment on python for ML/train_data.csv' ,nrows=200000)

# %%
traindata
# Out:
#                                               customer_ID         S_2  \
# 0       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
# ...                                                   ...         ...
# 199995  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-08-28
# 199996  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-09-15
# 199997  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-10-10
# 199998  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-11-16
# 199999  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-12-15
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# ...

# %%
trainlabel=pd.read_csv('C:/Users/91944/Desktop/INSOFE ASSIGNMENT/Assignment on python for ML/train_labels.csv' ,nrows=200000)

# %%
dataset=pd.merge(traindata,trainlabel,left_index=True,right_index=True)

# %%
dataset
# Out:
#                                             customer_ID_x         S_2  \
# 0       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
# ...                                                   ...         ...
# 199995  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-08-28
# 199996  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-09-15
# 199997  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-10-10
# 199998  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-11-16
# 199999  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-12-15
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# ...

# %% [markdown]
# ### Reading data for test case

# %%
testdata1=pd.read_csv('C:/Users/91944/Desktop/INSOFE ASSIGNMENT/Assignment on python for ML/test_data.csv',nrows=200000)

# %%
testlabel=pd.read_csv('C:/Users/91944/Desktop/INSOFE ASSIGNMENT/Assignment on python for ML/train_labels.csv' ,nrows=200000)

# %%
testdata=pd.merge(testdata1,testlabel,left_index=True,right_index=True)

# %%
testdata
# Out:
#                                             customer_ID_x         S_2  \
# 0       00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-02-19
# 1       00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-03-25
# 2       00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-04-25
# 3       00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-05-20
# 4       00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-06-15
# ...                                                   ...         ...
# 199995  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2018-12-14
# 199996  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-01-09
# 199997  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-02-22
# 199998  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-03-25
# 199999  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-04-21
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# ...

# %% [markdown]
# # Exploratory Data Analysis :

# %%
# printing the first 5 rows of the dataset
dataset.head(3)
# Out:
#                                        customer_ID_x         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709  ...
# 1  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714  ...
# 2  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423  ...
#
#    D_138     D_139     D_140     D_141  D_142     D_143     D_144     D_145  \
# 0    NaN  0.002427  0.003706  0.003818    NaN  0.000569  0.000610  0.002674
# 1    NaN  0.003954  0.003167  0.005032    NaN  0.009576  0.005492  0.009217
# 2    NaN  0.003269  0.007329  0.000427    NaN  0.003429  0.006986  0.002603
#
# ...

# %%
dataset.tail()
# Out:
#                                             customer_ID_x         S_2  \
# 199995  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-08-28
# 199996  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-09-15
# 199997  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-10-10
# 199998  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-11-16
# 199999  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-12-15
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 199995  0.539011  0.002428  0.006173  1.006607  0.007721  0.155389  0.002317
# 199996  0.545751  0.062144  0.014536  0.816225  0.009416  0.145824  0.007354
# 199997  0.579735  0.009152  0.010878  0.815024  0.005641  0.149669  0.001961
# 199998  0.577626  0.090158  0.013903  1.008488  0.007109  0.153834  0.004685
# 199999  0.655403  0.002060  0.022364  1.007560  0.006147  0.151334  0.009964
#
#              B_3  ...  D_138     D_139     D_140     D_141  D_142     D_143  \
# ...

# %%
# number of rows and Columns in this dataset
dataset.shape
# Out:
# (200000, 192)

# %%
#Reading the name of the columns

dataset.columns
# Out:
# Index(['customer_ID_x', 'S_2', 'P_2', 'D_39', 'B_1', 'B_2', 'R_1', 'S_3',
#        'D_41', 'B_3',
#        ...
#        'D_138', 'D_139', 'D_140', 'D_141', 'D_142', 'D_143', 'D_144', 'D_145',
#        'customer_ID_y', 'target'],
#       dtype='object', length=192)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 192 entries, customer_ID_x to target
# dtypes: float64(185), int64(2), object(5)
# memory usage: 293.0+ MB

# %%
dataset.dtypes
# Out:
# customer_ID_x     object
# S_2               object
# P_2              float64
# D_39             float64
# B_1              float64
#                   ...
# D_143            float64
# D_144            float64
# D_145            float64
# customer_ID_y     object
# target             int64
# Length: 192, dtype: object

# %% [markdown]
# ### EDA process for test case

# %%
testdata.head(3)
# Out:
#                                        customer_ID_x         S_2       P_2  \
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-02-19  0.631315
# 1  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-03-25  0.587042
# 2  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-04-25  0.609056
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001912  0.010728  0.814497  0.007547  0.168651  0.009971  0.002347  ...
# 1  0.005275  0.011026  0.810848  0.001817  0.241389  0.000166  0.009132  ...
# 2  0.003326  0.016390  1.004620  0.000114  0.266976  0.004196  0.004192  ...
#
#    D_138     D_139     D_140     D_141  D_142     D_143     D_144     D_145  \
# 0    NaN       NaN  0.004669       NaN    NaN       NaN  0.008281       NaN
# 1    NaN  0.000142  0.004940  0.009021    NaN  0.003695  0.003753  0.001460
# 2    NaN  0.000074  0.002114  0.004656    NaN  0.003155  0.002156  0.006482
#
# ...

# %%
testdata.tail(3)
# Out:
#                                             customer_ID_x         S_2  \
# 199997  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-02-22
# 199998  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-03-25
# 199999  0490d01489b6226511722eb94a84cede10b2c067d467f2...  2019-04-21
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 199997  0.935420  0.215794  0.036632  1.008096  0.008109  0.111907  0.001784
# 199998  0.941477  0.179642  0.027573  1.008244  0.003870  0.124180  0.001205
# 199999  0.939218  0.090217  0.042124  1.004468  0.000544  0.129382  0.004719
#
#              B_3  ...  D_138     D_139     D_140     D_141  D_142     D_143  \
# 199997  0.001253  ...    NaN  0.002692  0.003650  0.008935    NaN  0.002047
# 199998  0.002556  ...    NaN  0.009399  0.009096  0.000486    NaN  0.001375
# 199999  0.000294  ...    NaN  0.002409  0.009358  0.007805    NaN  0.001107
#
# ...

# %%
testdata.shape
# Out:
# (200000, 192)

# %%
testdata.columns
# Out:
# Index(['customer_ID_x', 'S_2', 'P_2', 'D_39', 'B_1', 'B_2', 'R_1', 'S_3',
#        'D_41', 'B_3',
#        ...
#        'D_138', 'D_139', 'D_140', 'D_141', 'D_142', 'D_143', 'D_144', 'D_145',
#        'customer_ID_y', 'target'],
#       dtype='object', length=192)

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 192 entries, customer_ID_x to target
# dtypes: float64(185), int64(2), object(5)
# memory usage: 293.0+ MB

# %%
testdata.dtypes
# Out:
# customer_ID_x     object
# S_2               object
# P_2              float64
# D_39             float64
# B_1              float64
#                   ...
# D_143            float64
# D_144            float64
# D_145            float64
# customer_ID_y     object
# target             int64
# Length: 192, dtype: object

# %% [markdown]
# ## Descriptive Statistics

# %%
dataset.describe(include='all')
# Out:
#                                             customer_ID_x         S_2  \
# count                                              200000      200000
# unique                                              16576         396
# top     0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-02-17
# freq                                                   13         933
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#                   P_2          D_39            B_1            B_2  \
# ...

# %%
dataset.mean()
# Out:
# C:\Users\91944\AppData\Local\Temp/ipykernel_46336/1799472221.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.mean()
# P_2       0.653527
# D_39      0.153413
# B_1       0.125356
# B_2       0.616971
# R_1       0.081215
#             ...
# D_142     0.392596
# D_143     0.179736
# D_144     0.053392
# D_145     0.061799
# target    0.259515
# Length: 187, dtype: float64

# %%
dataset.median()
# Out:
# C:\Users\91944\AppData\Local\Temp/ipykernel_46336/4167803218.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.median()
# P_2       0.691541
# D_39      0.009066
# B_1       0.031935
# B_2       0.814164
# R_1       0.005793
#             ...
# D_142     0.382038
# D_143     0.006078
# D_144     0.005499
# D_145     0.006060
# target    0.000000
# Length: 187, dtype: float64

# %%
# converting categorial in dataset

# %%
for col in ['customer_ID_x','S_2','customer_ID_y']:
    dataset[col] = dataset[col].astype('category')

# %%
dataset.dtypes
# Out:
# customer_ID_x    category
# S_2              category
# P_2               float64
# D_39              float64
# B_1               float64
#                    ...
# D_143             float64
# D_144             float64
# D_145             float64
# customer_ID_y    category
# target              int64
# Length: 192, dtype: object

# %%
# converting categorial in test dataset

# %%
testdata.dtypes
# Out:
# customer_ID_x     object
# S_2               object
# P_2              float64
# D_39             float64
# B_1              float64
#                   ...
# D_143            float64
# D_144            float64
# D_145            float64
# customer_ID_y     object
# target             int64
# Length: 192, dtype: object

# %%
for col in ['customer_ID_x','S_2','customer_ID_y']:
    testdata[col] = testdata[col].astype('category')

# %%
testdata.dtypes
# Out:
# customer_ID_x    category
# S_2              category
# P_2               float64
# D_39              float64
# B_1               float64
#                    ...
# D_143             float64
# D_144             float64
# D_145             float64
# customer_ID_y    category
# target              int64
# Length: 192, dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Droping Null value in traindataset

# %%
dataset.isnull().sum()
# Out:
# customer_ID_x       0
# S_2                 0
# P_2              1542
# D_39                0
# B_1                 0
#                  ...
# D_143            3503
# D_144            1433
# D_145            3503
# customer_ID_y       0
# target              0
# Length: 192, dtype: int64

# %%
dataset=dataset.drop(columns=['P_2','D_143','D_144','D_145' ])

# %%
dataset=dataset.drop(columns=['B_2','D_140','D_141','D_142' ])

# %%
dataset.isnull()
# Out:
#         customer_ID_x    S_2   D_39    B_1    R_1    S_3   D_41    B_3  D_42  \
# 0               False  False  False  False  False  False  False  False  True
# 1               False  False  False  False  False  False  False  False  True
# 2               False  False  False  False  False  False  False  False  True
# 3               False  False  False  False  False  False  False  False  True
# 4               False  False  False  False  False  False  False  False  True
# ...               ...    ...    ...    ...    ...    ...    ...    ...   ...
# 199995          False  False  False  False  False  False  False  False  True
# 199996          False  False  False  False  False  False  False  False  True
# 199997          False  False  False  False  False  False  False  False  True
# 199998          False  False  False  False  False  False  False  False  True
# 199999          False  False  False  False  False  False  False  False  True
#
# ...

# %%
#To insert the mean value of each column into its missing rows:
dataset.fillna(dataset.mean(numeric_only=True).round(1), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# customer_ID_x    0
# S_2              0
# D_39             0
# B_1              0
# R_1              0
#                 ..
# D_137            0
# D_138            0
# D_139            0
# customer_ID_y    0
# target           0
# Length: 184, dtype: int64

# %%
dataset.shape
# Out:
# (200000, 184)

# %%
dataset.dtypes
# Out:
# customer_ID_x    category
# S_2              category
# D_39              float64
# B_1               float64
# R_1               float64
#                    ...
# D_137             float64
# D_138             float64
# D_139             float64
# customer_ID_y    category
# target              int64
# Length: 184, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 184 entries, customer_ID_x to target
# dtypes: category(3), float64(177), int64(2), object(2)
# memory usage: 283.9+ MB

# %%
sum(dataset.isnull().sum())
# Out:
# 8040

# %%
dataset=dataset.dropna(axis=1)

# %%
dataset.isnull().sum()
# Out:
# customer_ID_x    0
# S_2              0
# D_39             0
# B_1              0
# R_1              0
#                 ..
# D_137            0
# D_138            0
# D_139            0
# customer_ID_y    0
# target           0
# Length: 183, dtype: int64

# %%
# mean value for test data
testdata.mean()
# Out:
# C:\Users\91944\AppData\Local\Temp/ipykernel_46336/4062900167.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   testdata.mean()
# P_2       0.658777
# D_39      0.156254
# B_1       0.127374
# B_2       0.615696
# R_1       0.074085
#             ...
# D_142     0.400784
# D_143     0.181895
# D_144     0.052003
# D_145     0.063137
# target    0.259515
# Length: 187, dtype: float64

# %% [markdown]
# ### Droping and filling mean value testdata

# %%
testdata.isnull().sum()
# Out:
# customer_ID_x       0
# S_2                 0
# P_2              1073
# D_39                0
# B_1                 0
#                  ...
# D_143            1699
# D_144             423
# D_145            1699
# customer_ID_y       0
# target              0
# Length: 192, dtype: int64

# %%
testdata=testdata.drop(columns=['P_2','D_143','D_144','D_145' ])

# %%
testdata.isnull().sum()
# Out:
# customer_ID_x         0
# S_2                   0
# D_39                  0
# B_1                   0
# B_2                  57
#                   ...
# D_140               420
# D_141              1699
# D_142            164900
# customer_ID_y         0
# target                0
# Length: 188, dtype: int64

# %%
testdata=testdata.drop(columns=['B_2','D_140','D_141','D_142' ])

# %%
testdata.isnull()
# Out:
#         customer_ID_x    S_2   D_39    B_1    R_1    S_3   D_41    B_3   D_42  \
# 0               False  False  False  False  False  False  False  False  False
# 1               False  False  False  False  False  False  False  False  False
# 2               False  False  False  False  False  False  False  False  False
# 3               False  False  False  False  False  False  False  False  False
# 4               False  False  False  False  False  False  False  False  False
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 199995          False  False  False  False  False  False  False  False   True
# 199996          False  False  False  False  False  False  False  False   True
# 199997          False  False  False  False  False  False  False  False   True
# 199998          False  False  False  False  False  False  False  False   True
# 199999          False  False  False  False  False  False  False  False   True
#
# ...

# %%
#To insert the mean value of each column into its missing rows:
testdata.fillna(dataset.mean(numeric_only=True).round(1), inplace=True)

# %%
testdata.isnull().sum()
# Out:
# customer_ID_x    0
# S_2              0
# D_39             0
# B_1              0
# R_1              0
#                 ..
# D_137            0
# D_138            0
# D_139            0
# customer_ID_y    0
# target           0
# Length: 184, dtype: int64

# %%
testdata.shape
# Out:
# (200000, 184)

# %%
sum(testdata.isnull().sum())
# Out:
# 6717

# %%
testdata=dataset.dropna(axis=1)

# %%
testdata.isnull().sum()
# Out:
# customer_ID_x    0
# S_2              0
# D_39             0
# B_1              0
# R_1              0
#                 ..
# D_137            0
# D_138            0
# D_139            0
# customer_ID_y    0
# target           0
# Length: 183, dtype: int64

# %%
testdata
# Out:
#                                             customer_ID_x         S_2  \
# 0       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4       0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
# ...                                                   ...         ...
# 199995  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-08-28
# 199996  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-09-15
# 199997  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-10-10
# 199998  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-11-16
# 199999  09572fafe01b8bbb560809da84c7d1c8d9e79eb7287bc5...  2017-12-15
#
#             D_39       B_1       R_1       S_3      D_41       B_3  D_42  \
# ...

# %% [markdown]
# # ENCODING CATEGORIAL DATA :

# %% [markdown]
# ### Label Encoder for train data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dataset['customer_ID_x'].value_counts()
# Out:
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a    13
# 05f0e502910eafa43254966634900102b547793a56cd275aaaec3fd1350ddfc4    13
# 05eebf93ac5095d37dc61f182bff1bc3f9e02aa366951807bd4a4b3abf0d8d13    13
# 05ef72d6f964d7af444ff77815851ad82cdd804d9295cd52c92054754548d12f    13
# 05ef792b3ee85dd86e9716fdc0ca548c4ccaa80d21f06faf3e68ac3da4307746    13
#                                                                     ..
# 0705e0885ac68589ce4dfd514ded2ab3062eb7715bb4a2ba70f12028011feee1     1
# 0868fab5e5ed544c7323ad1ea0d40d87b5f8b0108f8de0f128e5ff06df27eadc     1
# 02655021f60f0a410c4f5d952de643ff67609fa069e364afe8d300ff989fa01d     1
# 02658f861cff6bbaa6931ac7aeeb01e1e93a0fcd1a0ce5ac2c34524ade8c1cce     1
# 01004143311cebfe374e0759c5b0d348a754cac32810f5624a547b4b1c24b1db     1
# Name: customer_ID_x, Length: 16576, dtype: int64

# %%
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(dataset.customer_ID_x)

# %%
dataset['ID'] = labels

# %%
dataset.head(5)
# Out:
#                                        customer_ID_x         S_2      D_39  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.001733
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.005775
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.091505
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.002455
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.002483
#
#         B_1       R_1       S_3      D_41       B_3  D_42  D_43  ...  \
# 0  0.008724  0.009228  0.124035  0.008771  0.004709   0.2   0.2  ...
# 1  0.004923  0.006151  0.126750  0.000798  0.002714   0.2   0.2  ...
# 2  0.021655  0.006815  0.123977  0.007598  0.009423   0.2   0.2  ...
# 3  0.013683  0.001373  0.117169  0.000685  0.005531   0.2   0.2  ...
# 4  0.015193  0.007605  0.117325  0.004653  0.009312   0.2   0.2  ...
#
#        R_28  D_134  D_135  D_136  D_137  D_138     D_139  \
# ...

# %%
dataset=dataset.drop(columns=['customer_ID_x'])
dataset=dataset.drop(columns=['customer_ID_y'])

# %%
dataset=dataset.drop(columns=['S_2'])

# %%
dataset.head(5)
# Out:
#        D_39       B_1       R_1       S_3      D_41       B_3  D_42  D_43  \
# 0  0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2   0.2
# 1  0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2   0.2
# 2  0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2   0.2
# 3  0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2   0.2
# 4  0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2   0.2
#
#        D_44       B_4  ...     D_133      R_28  D_134  D_135  D_136  D_137  \
# 0  0.000630  0.080986  ...  0.004345  0.001535    0.3    0.0    0.2    0.0
# 1  0.002526  0.069419  ...  0.007495  0.004931    0.3    0.0    0.2    0.0
# 2  0.007605  0.068839  ...  0.009227  0.009123    0.3    0.0    0.2    0.0
# 3  0.006406  0.055630  ...  0.007206  0.002409    0.3    0.0    0.2    0.0
# 4  0.007731  0.038862  ...  0.006312  0.004462    0.3    0.0    0.2    0.0
#
#    D_138     D_139  target  ID
# 0    0.2  0.002427       0   0
# ...

# %%
dataset=pd.get_dummies(dataset)

# %%
dataset.head()
# Out:
#        D_39       B_1       R_1       S_3      D_41       B_3  D_42  D_43  \
# 0  0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2   0.2
# 1  0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2   0.2
# 2  0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2   0.2
# 3  0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2   0.2
# 4  0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2   0.2
#
#        D_44       B_4  ...  D_138     D_139  target  ID  D_63_CL  D_63_CO  \
# 0  0.000630  0.080986  ...    0.2  0.002427       0   0        0        0
# 1  0.002526  0.069419  ...    0.2  0.003954       0   0        0        0
# 2  0.007605  0.068839  ...    0.2  0.003269       0   0        0        0
# 3  0.006406  0.055630  ...    0.2  0.006117       0   0        0        0
# 4  0.007731  0.038862  ...    0.2  0.003671       0   0        0        0
#
#    D_63_CR  D_63_XL  D_63_XM  D_63_XZ
# ...

# %%
dataset.isnull().sum()
# Out:
# D_39       0
# B_1        0
# R_1        0
# S_3        0
# D_41       0
#           ..
# D_63_CO    0
# D_63_CR    0
# D_63_XL    0
# D_63_XM    0
# D_63_XZ    0
# Length: 186, dtype: int64

# %%
dataset=dataset.drop(columns=['D_63_CL','D_63_CR','D_63_XL','D_63_XM' ,'D_63_XZ' ])

# %%
dataset.isnull
# Out:
# <bound method DataFrame.isnull of             D_39       B_1       R_1       S_3      D_41       B_3  D_42  \
# 0       0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2
# 1       0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2
# 2       0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2
# 3       0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2
# 4       0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2
# ...          ...       ...       ...       ...       ...       ...   ...
# 199995  0.002428  0.006173  0.007721  0.155389  0.002317  0.014583   0.2
# 199996  0.062144  0.014536  0.009416  0.145824  0.007354  0.011436   0.2
# 199997  0.009152  0.010878  0.005641  0.149669  0.001961  0.008332   0.2
# 199998  0.090158  0.013903  0.007109  0.153834  0.004685  0.010484   0.2
# 199999  0.002060  0.022364  0.006147  0.151334  0.009964  0.003983   0.2
#
# ...

# %%
dataset.isnull().sum()
# Out:
# D_39       0
# B_1        0
# R_1        0
# S_3        0
# D_41       0
#           ..
# D_138      0
# D_139      0
# target     0
# ID         0
# D_63_CO    0
# Length: 181, dtype: int64

# %%
dataset=dataset.drop(columns=['D_63_CO'])

# %%
dataset.isnull().sum()
# Out:
# D_39      0
# B_1       0
# R_1       0
# S_3       0
# D_41      0
#          ..
# D_137     0
# D_138     0
# D_139     0
# target    0
# ID        0
# Length: 180, dtype: int64

# %%
dataset.shape
# Out:
# (200000, 180)

# %% [markdown]
# ### Label Encoder for test dataset

# %%
from sklearn.preprocessing import LabelEncoder

# %%
testdata['customer_ID_x'].value_counts()
# Out:
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a    13
# 05f0e502910eafa43254966634900102b547793a56cd275aaaec3fd1350ddfc4    13
# 05eebf93ac5095d37dc61f182bff1bc3f9e02aa366951807bd4a4b3abf0d8d13    13
# 05ef72d6f964d7af444ff77815851ad82cdd804d9295cd52c92054754548d12f    13
# 05ef792b3ee85dd86e9716fdc0ca548c4ccaa80d21f06faf3e68ac3da4307746    13
#                                                                     ..
# 0705e0885ac68589ce4dfd514ded2ab3062eb7715bb4a2ba70f12028011feee1     1
# 0868fab5e5ed544c7323ad1ea0d40d87b5f8b0108f8de0f128e5ff06df27eadc     1
# 02655021f60f0a410c4f5d952de643ff67609fa069e364afe8d300ff989fa01d     1
# 02658f861cff6bbaa6931ac7aeeb01e1e93a0fcd1a0ce5ac2c34524ade8c1cce     1
# 01004143311cebfe374e0759c5b0d348a754cac32810f5624a547b4b1c24b1db     1
# Name: customer_ID_x, Length: 16576, dtype: int64

# %%
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(testdata.customer_ID_x)

# %%
testdata['ID'] = labels

# %%
testdata.head(5)
# Out:
#                                        customer_ID_x         S_2      D_39  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.001733
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.005775
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.091505
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.002455
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.002483
#
#         B_1       R_1       S_3      D_41       B_3  D_42  D_43  ...  \
# 0  0.008724  0.009228  0.124035  0.008771  0.004709   0.2   0.2  ...
# 1  0.004923  0.006151  0.126750  0.000798  0.002714   0.2   0.2  ...
# 2  0.021655  0.006815  0.123977  0.007598  0.009423   0.2   0.2  ...
# 3  0.013683  0.001373  0.117169  0.000685  0.005531   0.2   0.2  ...
# 4  0.015193  0.007605  0.117325  0.004653  0.009312   0.2   0.2  ...
#
#        R_28  D_134  D_135  D_136  D_137  D_138     D_139  \
# ...

# %%
testdata=testdata.drop(columns=['customer_ID_x'])
testdata=testdata.drop(columns=['customer_ID_y'])

# %%
testdata=testdata.drop(columns=['S_2'])

# %%
testdata.head(5)
# Out:
#        D_39       B_1       R_1       S_3      D_41       B_3  D_42  D_43  \
# 0  0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2   0.2
# 1  0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2   0.2
# 2  0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2   0.2
# 3  0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2   0.2
# 4  0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2   0.2
#
#        D_44       B_4  ...     D_133      R_28  D_134  D_135  D_136  D_137  \
# 0  0.000630  0.080986  ...  0.004345  0.001535    0.3    0.0    0.2    0.0
# 1  0.002526  0.069419  ...  0.007495  0.004931    0.3    0.0    0.2    0.0
# 2  0.007605  0.068839  ...  0.009227  0.009123    0.3    0.0    0.2    0.0
# 3  0.006406  0.055630  ...  0.007206  0.002409    0.3    0.0    0.2    0.0
# 4  0.007731  0.038862  ...  0.006312  0.004462    0.3    0.0    0.2    0.0
#
#    D_138     D_139  target  ID
# 0    0.2  0.002427       0   0
# ...

# %%
testdata=pd.get_dummies(testdata)

# %%
testdata.head()
# Out:
#        D_39       B_1       R_1       S_3      D_41       B_3  D_42  D_43  \
# 0  0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2   0.2
# 1  0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2   0.2
# 2  0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2   0.2
# 3  0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2   0.2
# 4  0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2   0.2
#
#        D_44       B_4  ...  D_138     D_139  target  ID  D_63_CL  D_63_CO  \
# 0  0.000630  0.080986  ...    0.2  0.002427       0   0        0        0
# 1  0.002526  0.069419  ...    0.2  0.003954       0   0        0        0
# 2  0.007605  0.068839  ...    0.2  0.003269       0   0        0        0
# 3  0.006406  0.055630  ...    0.2  0.006117       0   0        0        0
# 4  0.007731  0.038862  ...    0.2  0.003671       0   0        0        0
#
#    D_63_CR  D_63_XL  D_63_XM  D_63_XZ
# ...

# %%
testdata.isnull
# Out:
# <bound method DataFrame.isnull of             D_39       B_1       R_1       S_3      D_41       B_3  D_42  \
# 0       0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2
# 1       0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2
# 2       0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2
# 3       0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2
# 4       0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2
# ...          ...       ...       ...       ...       ...       ...   ...
# 199995  0.002428  0.006173  0.007721  0.155389  0.002317  0.014583   0.2
# 199996  0.062144  0.014536  0.009416  0.145824  0.007354  0.011436   0.2
# 199997  0.009152  0.010878  0.005641  0.149669  0.001961  0.008332   0.2
# 199998  0.090158  0.013903  0.007109  0.153834  0.004685  0.010484   0.2
# 199999  0.002060  0.022364  0.006147  0.151334  0.009964  0.003983   0.2
#
# ...

# %%
testdata=testdata.drop(columns=['D_63_CL','D_63_CR','D_63_XL','D_63_XM' ,'D_63_XZ' ])

# %%
testdata.isnull
# Out:
# <bound method DataFrame.isnull of             D_39       B_1       R_1       S_3      D_41       B_3  D_42  \
# 0       0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2
# 1       0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2
# 2       0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2
# 3       0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2
# 4       0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2
# ...          ...       ...       ...       ...       ...       ...   ...
# 199995  0.002428  0.006173  0.007721  0.155389  0.002317  0.014583   0.2
# 199996  0.062144  0.014536  0.009416  0.145824  0.007354  0.011436   0.2
# 199997  0.009152  0.010878  0.005641  0.149669  0.001961  0.008332   0.2
# 199998  0.090158  0.013903  0.007109  0.153834  0.004685  0.010484   0.2
# 199999  0.002060  0.022364  0.006147  0.151334  0.009964  0.003983   0.2
#
# ...

# %%
testdata=testdata.drop(columns=['D_63_CO' ])

# %%
testdata.isnull
# Out:
# <bound method DataFrame.isnull of             D_39       B_1       R_1       S_3      D_41       B_3  D_42  \
# 0       0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2
# 1       0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2
# 2       0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2
# 3       0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2
# 4       0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2
# ...          ...       ...       ...       ...       ...       ...   ...
# 199995  0.002428  0.006173  0.007721  0.155389  0.002317  0.014583   0.2
# 199996  0.062144  0.014536  0.009416  0.145824  0.007354  0.011436   0.2
# 199997  0.009152  0.010878  0.005641  0.149669  0.001961  0.008332   0.2
# 199998  0.090158  0.013903  0.007109  0.153834  0.004685  0.010484   0.2
# 199999  0.002060  0.022364  0.006147  0.151334  0.009964  0.003983   0.2
#
# ...

# %%
sum(testdata.isnull().sum())
# Out:
# 0

# %%
testdata=testdata.dropna(axis=1)
testdata
# Out:
#             D_39       B_1       R_1       S_3      D_41       B_3  D_42  \
# 0       0.001733  0.008724  0.009228  0.124035  0.008771  0.004709   0.2
# 1       0.005775  0.004923  0.006151  0.126750  0.000798  0.002714   0.2
# 2       0.091505  0.021655  0.006815  0.123977  0.007598  0.009423   0.2
# 3       0.002455  0.013683  0.001373  0.117169  0.000685  0.005531   0.2
# 4       0.002483  0.015193  0.007605  0.117325  0.004653  0.009312   0.2
# ...          ...       ...       ...       ...       ...       ...   ...
# 199995  0.002428  0.006173  0.007721  0.155389  0.002317  0.014583   0.2
# 199996  0.062144  0.014536  0.009416  0.145824  0.007354  0.011436   0.2
# 199997  0.009152  0.010878  0.005641  0.149669  0.001961  0.008332   0.2
# 199998  0.090158  0.013903  0.007109  0.153834  0.004685  0.010484   0.2
# 199999  0.002060  0.022364  0.006147  0.151334  0.009964  0.003983   0.2
#
#             D_43      D_44       B_4  ...     D_133      R_28  D_134  D_135  \
# ...

# %%
testdata.isnull().sum()
# Out:
# D_39      0
# B_1       0
# R_1       0
# S_3       0
# D_41      0
#          ..
# D_137     0
# D_138     0
# D_139     0
# target    0
# ID        0
# Length: 180, dtype: int64

# %%
testdata.shape
# Out:
# (200000, 180)

# %% [markdown]
# # DATA VISUALIZATION :

# %%
# Correlation

# %%
dataset.corr()
# Out:
#             D_39       B_1       R_1       S_3      D_41       B_3      D_42  \
# D_39    1.000000  0.186927  0.202069  0.070005  0.446359  0.173927  0.031639
# B_1     0.186927  1.000000  0.228320  0.157623  0.193610  0.719903 -0.030802
# R_1     0.202069  0.228320  1.000000  0.211109  0.285458  0.271392  0.075691
# S_3     0.070005  0.157623  0.211109  1.000000  0.084710  0.131836  0.063464
# D_41    0.446359  0.193610  0.285458  0.084710  1.000000  0.245605  0.021396
# ...          ...       ...       ...       ...       ...       ...       ...
# D_137  -0.001902  0.008985  0.015205  0.017589  0.004775  0.006821  0.009337
# D_138   0.005037 -0.007634  0.005057  0.002493  0.007098 -0.012042 -0.005052
# D_139   0.031696  0.109677  0.083206  0.051145  0.050396  0.136735 -0.004301
# target  0.003905  0.003671  0.000888  0.000622  0.003303  0.002517  0.003810
# ID     -0.003397 -0.005006  0.002741  0.000650  0.000908  0.003341  0.000319
#
# ...

# %%
# calculating the correlation of complete dataset

corr = dataset.corr()
corr
# Out:
#             D_39       B_1       R_1       S_3      D_41       B_3      D_42  \
# D_39    1.000000  0.186927  0.202069  0.070005  0.446359  0.173927  0.031639
# B_1     0.186927  1.000000  0.228320  0.157623  0.193610  0.719903 -0.030802
# R_1     0.202069  0.228320  1.000000  0.211109  0.285458  0.271392  0.075691
# S_3     0.070005  0.157623  0.211109  1.000000  0.084710  0.131836  0.063464
# D_41    0.446359  0.193610  0.285458  0.084710  1.000000  0.245605  0.021396
# ...          ...       ...       ...       ...       ...       ...       ...
# D_137  -0.001902  0.008985  0.015205  0.017589  0.004775  0.006821  0.009337
# D_138   0.005037 -0.007634  0.005057  0.002493  0.007098 -0.012042 -0.005052
# D_139   0.031696  0.109677  0.083206  0.051145  0.050396  0.136735 -0.004301
# target  0.003905  0.003671  0.000888  0.000622  0.003303  0.002517  0.003810
# ID     -0.003397 -0.005006  0.002741  0.000650  0.000908  0.003341  0.000319
#
# ...

# %% [markdown]
# ## Analyzing The Correlated Features

# %%
plt.scatter(dataset['R_1'],dataset['D_86'])
plt.xlabel("Spend variable")
plt.ylabel("Delinquency variables")
# Out:
# Text(0, 0.5, 'Delinquency variables')

# %%
import seaborn as sns
sns.regplot(x="R_1",y="D_86",data=dataset)
# Out:
# <AxesSubplot:xlabel='R_1', ylabel='D_86'>

# %%
# Visulaizing the heatmap of complete dataset

sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # X-y split (Input-Output Split)

# %%
from sklearn.model_selection import train_test_split

# %%
y=dataset['target']
X=dataset.drop('target',axis=1)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.50,random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (100000, 179)
# (100000, 179)
# (100000,)
# (100000,)

# %%
num_attr=X_train.select_dtypes(['int64','float64']).columns
num_attr
# Out:
# Index(['D_39', 'B_1', 'R_1', 'S_3', 'D_41', 'B_3', 'D_42', 'D_43', 'D_44',
#        'B_4',
#        ...
#        'D_131', 'D_132', 'D_133', 'R_28', 'D_134', 'D_135', 'D_136', 'D_137',
#        'D_138', 'D_139'],
#       dtype='object', length=178)

# %% [markdown]
# # Standardizing the data

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[ 7.83232479e-01,  4.91489748e-01, -3.42364880e-01, ...,
#          2.85824217e-02, -4.53074304e-01,  1.17202011e+00],
#        [-4.49281229e-01,  3.77419404e-01, -3.27864292e-01, ...,
#          2.85824217e-02,  2.18742079e+00, -1.94756482e-01],
#        [-5.36412147e-01,  3.67614764e+00, -3.34715567e-01, ...,
#          2.85824217e-02,  2.20273655e+00, -1.04786906e+00],
#        ...,
#        [-5.32091730e-01, -6.01583458e-02, -3.22694208e-01, ...,
#          2.85824217e-02,  2.19334779e+00, -3.86936593e-01],
#        [-5.33565336e-01,  7.14269718e-02,  2.95709885e+00, ...,
#          2.85824217e-02,  2.18960738e+00, -7.58972221e-01],
#        [ 2.86981236e-03,  3.15977963e+00, -3.42739077e-01, ...,
#          2.85824217e-02, -4.67481445e-01, -1.06834042e+00]])

# %%
X_test
# Out:
# array([[ 0.21570245,  0.12402737, -0.34376446, ...,  0.02858242,
#         -0.46444224,  1.39093833],
#        [ 0.1048928 , -0.36292859, -0.32266089, ...,  0.02858242,
#         -0.45488427, -1.57887106],
#        [-0.41859216,  2.61876251, -0.324533  , ...,  0.02858242,
#         -0.45963555, -0.39738116],
#        ...,
#        [ 4.71814981, -0.1160871 ,  7.33873708, ...,  0.02858242,
#         -0.45229582,  1.66395942],
#        [ 0.23693209,  2.6932608 ,  0.74925364, ...,  0.02858242,
#         -0.46777407,  1.04877417],
#        [-0.54811524, -0.58234353, -0.34300357, ...,  0.02858242,
#         -0.4784086 ,  1.2405365 ]])

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_train_pred1=lr.predict(X_train)

# %%
print("accuracy of the model:",metrics.accuracy_score(y_train,y_train_pred1))
# Out:
# accuracy of the model: 0.7416

# %% [markdown]
# ### for test data

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_test_pred2=lr.predict(X_test)

# %%
print("accuracy of the model:",metrics.accuracy_score(y_test,y_test_pred2))
# Out:
# accuracy of the model: 0.73937

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import f1_score

# %%
print(confusion_matrix(y_test,y_train_pred1))
print(classification_report(y_test,y_train_pred1))
print("F1 Score :",f1_score(y_test,y_train_pred1))
# Out:
# [[73934     4]
#  [26061     1]]
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85     73938
#            1       0.20      0.00      0.00     26062
#
#     accuracy                           0.74    100000
#    macro avg       0.47      0.50      0.43    100000
# weighted avg       0.60      0.74      0.63    100000
#
# F1 Score : 7.672536156826638e-05

# %% [markdown]
# # Prediction for test data

# %%
df1=pd.DataFrame(testdata['ID'],columns=['ID'])
df2=pd.DataFrame(y_test_pred2,columns=['target'])
df=pd.concat([df1,df2], axis=1)
df
# Out:
#            ID  target
# 0           0     0.0
# 1           0     0.0
# 2           0     0.0
# 3           0     0.0
# 4           0     0.0
# ...       ...     ...
# 199995  16575     NaN
# 199996  16575     NaN
# 199997  16575     NaN
# 199998  16575     NaN
# 199999  16575     NaN
#
# [200000 rows x 2 columns]

# %%
# Save to csv file
df.to_csv('Americanexpress1.csv')

# %% [markdown]
# ### ThankYou
